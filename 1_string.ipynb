# %% [markdown]
# # String metodlari.
# ---
#
# **Eslatma**: String(matn) metodlari faqat yangi qiymat qaytaradi. Haqiqiy matnni o'zgatirmaydi.
#
# **Batafsil**: [Python String methods](https://www.w3schools.com/PYTHON/python_ref_string.asp)

# %% [markdown]
# ## 1. capitalize()
# ---
#
# **Tushuntirish**: Matnning birinchi belgisini katta harfga o'zgartiradi, agar raqam bo'lsa o'zgarishsiz qoladi.
#
# **Sintaksis**:
# ```
# "mening matnim".capitalize()
# ```

# %%
# Oddiy matn
matn = "men Azizbek Jabborov Python dasturchisiman."
yangi_matn = matn.capitalize()
print("Eski matn:", matn)
print("Yangi matn:", yangi_matn)
# Out:
# Eski matn: men Azizbek Jabborov Python dasturchisiman.
# Yangi matn: Men azizbek jabborov python dasturchisiman.

# %%
# Birinchi belgi raqam bo'lsa
raqamli_matn = "18 soni 9 ga bo'linadi."
yangi_raqamli_matn = raqamli_matn.capitalize()
print("Eski matn:", raqamli_matn)
print("Yangi matn:", yangi_raqamli_matn)
# Out:
# Eski matn: 18 soni 9 ga bo'linadi.
# Yangi matn: 18 soni 9 ga bo'linadi.

# %% [markdown]
# ## 2. casefold()
# ---
#
# **Tushuntirish**: Berilgan matnning barcha belgilarini kichik harfga o'giradi.
#
# **Sintaksis**:
# ```
# "mening matnim".casefold()
# ```

# %%
aralash_matn = "Men juda baxtiyorman."
kichik_matn = aralash_matn.casefold()
print("Aralash matn:", aralash_matn)
print("Kichik matn:", kichik_matn)
# Out:
# Aralash matn: Men juda baxtiyorman.
# Kichik matn: men juda baxtiyorman.

# %% [markdown]
# ## 3. center()
# ---
#
# **Tushuntirish**: Berilgan matnni eksi o'lchovidan _uzunlik_ o'lchoviga o'zgartirib, matnni markazlashtiradi. Matnning chap va o'ng tomonini kiritilgan _qiymat_ bilan to'ldiriladi. Agar qiymat berilmasa bo'sh joy(" ") bilan to'ldiradi.
#
# **Sintaksis**:
# ```
# matn.center(uzunlik, qiymat)
# ```
#
# Bu yerda:
# - **uzunlik**: Majburiy parametr. Agar bu parametr kirtilmasa xatolik kelib chiqadi.
# - **qiymat**: Ixtiyoriy parametr. Matnning chap va o'ng tomoniga _uzunlik_ marta to'ldiriladi.

# %%
# Oddiy hol. Bo'sh jo'y bilan to'ldirish
matn = "mevalar"
yangi_matn = matn.center(10) 
print("Eski matn:", matn, "Uzunligi:", len(matn)) # Eski matnnig uzunligi 7.
print("Yangi matn:", yangi_matn, "Uzunligi:", len(yangi_matn)) # Matn markazlashtirildi va 7 o'lchovli matndan bo'sh qiymat(" ") yordamida 10 o'lchovli matnga o'zgaritirildi.
# Out:
# Eski matn: mevalar Uzunligi: 7
# Yangi matn:  mevalar   Uzunligi: 10

# %%
yangi_matn
# Out:
# ' mevalar  '

# %%
# Maxsus bilgi bilan to'ldirish
matn = "mevalar"
yangi_matn = matn.center(10, "A") 
print("Eski matn:", matn, "Uzunligi:", len(matn)) # Eski matnnig uzunligi 7.
print("Yangi matn:", yangi_matn, "Uzunligi:", len(yangi_matn)) # Matn markazlashtirildi va 7 o'lchovli matndan "A" belgisi yordamida 10 o'lchovli matnga o'zgaritirildi.
# Out:
# Eski matn: mevalar Uzunligi: 7
# Yangi matn: AmevalarAA Uzunligi: 10

# %%
yangi_matn
# Out:
# 'AmevalarAA'

# %% [markdown]
# ## 4. count()
# ---
#
# **Tushuntirish**: Berilgan matndan barchan uchraga _qiymat_ sonini qaytaradi.
#
# **Sintaksis**:
# ```
# matn.count(qiymat, boshlanish, tugash)
# ```
#
# Bu yerda:
# - **qiymat**: Majburiy parametr. Faqat bilgilardan iborat matnni qabul qiladi. Qidirilishi kerak bo'lgan matn.
# - **boshlanish**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
# - **tugash**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi. Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol.
matn = "Men olmalarni juda yaxshi ko'raman va olmalar juda mazali meva."
olma_soni = matn.count("olma")
print("Berilgan matndagi 'olma' soni:", olma_soni, "ta.")
# Out:
# Berilgan matndagi 'olma' soni: 2 ta.

# %%
# Maxsus hol. 'olma' so'zini 10- va 50- indekslar orasidan izlash.
matn = "Men olmalarni juda yaxshi ko'raman va olmalar juda mazali meva."
qiymat = "olma"
boshlanish = 10
tugash = 50
olma_soni = matn.count(qiymat, boshlanish, tugash)
print(f"{boshlanish}-indeksdan {tugash}-indeksigacha bo'lgan qismdan 'olma' soni:", olma_soni, "ta.")
# Out:
# 10-indeksdan 50-indeksigacha bo'lgan qismdan 'olma' soni: 1 ta.

# %% [markdown]
# ## 5. encode()
# ---
#
# **Tushuntirish**: Berilgan matnni kodga o'giradi.
#
# **Sintaksis**:
# ```
# matn.encode(encoding, errors)
# ```
#
# Bu yerda:
# - **encoding**: Ixtiyoriy parametr. Matnli(string) qiymat qabul qiladi. Jimlik bo'yicha 'UTF-8'.
# - **errors**: Ixtiyoriy parametr. Matnli(string) qiymat qabul qiladi.
#
#     Agar matndagi ma'lum bir belgi kodlashtirilmasa, yuzaga keladigan xatolikni oldinini olsih uchun ishlatiladi.
#
#     Bu parametr quyidagi qiymatlarni qabul qiladi:
#     - ```'backslashreplace'```: Kodlashtirilmagan belgi o'rniga bekslesh(\\) belgisini qo'yadi.
#     - ```'ignore'```: Kodlashtirilmagan belgi matnnda olib tashlaniladi.
#     - ```'namereplace'```: Kodlashtirilmagan belgi o'rniga o'sha belgining tavsifini joylaydi.
#     - ```'strict'```: Jimlik bo'yicha qiymat. Xatolik keltirib chiqaradi.
#     - ```'replace'```: Kodlashtirilmagan belgi o'rniga so'roq belgisi(?) belgisini qo'yadi.
#     - ```'xmlcharrefreplace'```: Kodlashtirilmagan belgi o'rniga xml belgisini qo'yadi.

# %%
txt = "My name is Ståle"

print(txt.encode(encoding="ascii",errors="backslashreplace"))
print(txt.encode(encoding="ascii",errors="ignore"))
print(txt.encode(encoding="ascii",errors="namereplace"))
print(txt.encode(encoding="ascii",errors="replace"))
print(txt.encode(encoding="ascii",errors="xmlcharrefreplace"))
# Out:
# b'My name is St\\xe5le'
# b'My name is Stle'
# b'My name is St\\N{LATIN SMALL LETTER A WITH RING ABOVE}le'
# b'My name is St?le'
# b'My name is St&#229;le'

# %% [markdown]
# ## 6. endswith()
# ---
#
# **Tushuntirish**: Agar matn berilgan _qiymat_ bilan tugasa rost(True) qaytaradi, aks holda yolg'on(False).
#
# **Sintaksis**:
# ```
# matn.endswith(qiymat, boshlanish, tugash)
# ```
#
# Bu yerda:
# - **qiymat**: Majburiy parametr. String(matn) yoki tuple(qator) bo'lishi mumkin. Agar tuple kiritilgan bo'lsa va matnning oxiri tuple ichidagi birorta element bilan tugasa rost qaytaradi.
# - **boshlanish**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
# - **tugash**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi. Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol
matn = "Mening ismim Azizbek"
qism = "bek"
natija = matn.endswith(qism)

if natija:
    print(f"Berilgan matn '{qism}' so'zi bilan tugaydi.")
else:
    print(f"Berilgan matn '{qism}' so'zi bilan tugamaydi.")
# Out:
# Berilgan matn 'bek' so'zi bilan tugaydi.

# %%
# Maxsus hol: Kerakli qismdan izlash
matn = "Mening ismim Azizbek"
qism = "bek"
boshlanish = 10
tugash = len(matn) - 2
natija = matn.endswith(qism, boshlanish, tugash)

if natija:
    print(f"Berilgan matn {boshlanish}-indeksdan  {tugash - 1}-indeksi oralig'ida '{qism}' so'zi bilan tugaydi.")
    print(f"Kerakli qism: {matn[boshlanish: tugash]}")
else:
    print(f"Berilgan matn {boshlanish}-indeksdan  {tugash - 1}-indeksi oralig'ida '{qism}' so'zi bilan tugamaydi.")
    print(f"Kerakli qism: {matn[boshlanish: tugash]}")
# Out:
# Berilgan matn 10-indeksdan  17-indeksi oralig'ida 'bek' so'zi bilan tugamaydi.
# Kerakli qism: im Azizb

# %%
# Maxsus hol.
matn = "Mening ismim Azizbek"
qismlar = ("bek", "zbek")
natija = matn.endswith(qismlar)

if natija:
    print(f"Berilgan matn '{qismlar}' ichidagi biror so'z bilan tugaydi.")
else:
    print(f"Berilgan matn '{qismlar}' ichidagi biror so'z bilan tugamaydi.")
# Out:
# Berilgan matn '('bek', 'zbek')' ichidagi biror so'z bilan tugaydi.

# %% [markdown]
# ## 7. expnadtabs()
# ---
#
# **Tushuntirish**: Matndagi tab(\t)lar o'rniga ma'lum bir son miqdor bo'sh joy(" ") bilan o'zgartiradi.
#
# **Sintaksis**:
# ```
# matn.expandtabs(tabsize)
# ```
#
# Bu yerda:
# -   **tabsize**: Ixtiyoriy parametr. Butun son(integer) qabul qiladi. Tab belgisi o'rniga nechta bo'sh qo'yishni bildiradi. Jimlik bo'yicha 7.
#
#     Misol uchun agar ```tabsize=7``` bo'lsa, matndagi har bitta tab belgisi o'rniga ```6``` bo'sh joy qo'yiladi.
#
# **Eslatma**: ```Tab``` - bu 4 bo'sh joydan iborat matn. Pythonda tabning uzunligi 1 ga teng. Quyidagi kod orqali tekshirib ko'ring.
# ```
# len("\t") # Natijasi 1 chiqadi.
# ```

# %%
matn = "M\te\ti\tn\ti\tn\tg"
print(f"Haqiqiy matn. Uzunligi: {len(matn)} ga teng.", ) # Haqiqiy matn
print(matn)

# Tushutirish:
#   - Matnda jami bo'lib 7 harf va 6 ta tab bor.
#   - Shunday ekan matnning uzunligi 13 ga teng bo'ladi.
# Out:
# Haqiqiy matn. Uzunligi: 13 ga teng.
# M	e	i	n	i	n	g

# %%
print(matn.expandtabs(3)) # Matndagi barcha tab belgisi o'rniga 2 ta bo'sh joy qo'yish
print(matn.expandtabs()) #  Matndagi barcha tab belgisi o'rniga 7 ta(jimlik bo'yicha) bo'sh joy qo'yish.
print(matn.expandtabs(10)) # Matndagi barcha tab belgisi o'rniga 9 ta bo'sh joy qo'yish

# Tushuntirish:
#   - Oxirgi misolda tabsize=10 kiritdik.
#   - Matnnig 0-indeksida 'M' belgisi, 10-indeksida esa 'e' belgisi joylashgan.
#   - 'M' va 'e' belgilari o'rtasida 9 ta bo'sh joy(probel) bor.
# Out:
# M  e  i  n  i  n  g
# M       e       i       n       i       n       g
# M         e         i         n         i         n         g

# %% [markdown]
# ## 8. find()
# ---
#
# **Tushuntirish**: Matnda maxsus _qiymat_ borligini tekshradi. Agar mavjud bo'lsa uchralgan birinchi indeksni qaytardi, aks holda ```-1```.
#
# **Sintaksis**:
# ```python
# matn.find(value, start, stop)
# ```
#
# Bu yerda:
# - **value**(qiymat): Majburiy parametr. Faqat bilgilardan iborat matnni qabul qiladi. Qidirilishi kerak bo'lgan matn.
# - **start**(boshlanish): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
# - **stop**(tugash): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi. Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol
matn = "Mening ismim Azizbek"
qism = "A"
natija = matn.find(qism)

if natija != -1:
    print(f"'{qism}' so'zi '{matn}' matnida mavjud. U {natija}-indeksida uchraydi.")
else:
    print(f"'{qism}' so'zi '{matn}' matnida mavjud emas.")
# Out:
# 'A' so'zi 'Mening ismim Azizbek' matnida mavjud. U 13-indeksida uchraydi.

# %%
# Maxsus hol
matn = "Mening ismim Azizbek"
qism = "i"
boshlanish = 2
tugash = 10
natija = matn.find(qism, boshlanish, tugash)

if natija != -1:
    print(f"'{qism}' so'zi '{matn[boshlanish: tugash]}' matnida mavjud. U {natija}-indeksida uchraydi.")
else:
    print(f"'{qism}' so'zi '{matn[boshlanish: tugash]}' matnida mavjud emas.")

# Tushuntirish:
#   - Matndan 'i' belgisi 2- va 10- indekslar orasida qidirilmoqda,
#   - 'i' belgisi matnda birinchi bo'lib 3 - indeksda(4-xonada) mavjud.
# Out:
# 'i' so'zi 'ning ism' matnida mavjud. U 3-indeksida uchraydi.

# %% [markdown]
# ## 9. format()
# ---
#
# **Tushuntirish**: Matnnig ichiga maxsus usul bilan qiymatlar joylanadi.
#
# **Sintaksis**:
# ```
# matn.format(value1, value2, ...)
# ```
#
# Bu yerda:
# -   **value1**, **value2**, ... : Majburiy parametrlar. Kalit=qiymat usuli yoki vergul bilan ajratilgan holda indekslar yordamida to'ldirish mumkin.

# %%
matn1 = "Mening ismim {ism}. Yoshim {yosh} da".format(ism="Azizbek", yosh=20) # kalit=qiymat usuli bilan to'ldirish
matn2 = "Mening ismim {0}. Yoshim {1} da".format("Azizbek", 20) # Vergul bilan ajratilgan holda indeks bilan to'ldirish.
matn3 = "Mening ismim {}. Yoshim {} da".format("Azizbek", 20) # Vergul bilan ajratilgan holda ketma-ket to'ldirish. Jimlik bo'yicha.

print(matn1)
print(matn2)
print(matn3)
# Out:
# Mening ismim Azizbek. Yoshim 20 da
# Mening ismim Azizbek. Yoshim 20 da
# Mening ismim Azizbek. Yoshim 20 da

# %%
# Maxsus hollar.
matn4 = "Siz to'pladingiz {:%}" # vergul bilan xona aniqligida ko'rsatish.
print(matn4.format(0.215))

matn5 = "Siz to'pladingiz {:.0%}" # Hech qanday aniqliksiz.
print(matn5.format(0.25))
# Out:
# Siz to'pladingiz 21.500000%
# Siz to'pladingiz 25%

# %% [markdown]
# ## 10. format_map()
# ---
#
# **Tushuntirish**: Lug'at(dict) yordamida matnni formatlash usuli.
#
# **Sintaksis**:
# ```
# matn.format_map(dictionary)
# ```
#
# Bu yerda:
# -   **dictionary**(lug'at): Majburiy parametr. Faqat lug'at(dict) ma'lumot turini qabul qiladi. Matnning kerakli qismini lug'atdagi kalitlar va qiymatlar yordamida to'ldirish uchun ishlatiladi.

# %%
matn = "Mening ismim {ism}. Yoshim {yosh} da"
lugat = {"ism": "Azizbek", "yosh": 20}
yangi_matn = matn.format_map(lugat)
print(yangi_matn)

# Tushuntirish:
#   - Matnda {ism} va {yosh} qismlari mavjud. 
#   - Lug'atda ham "ism" va "yosh" nomli kalitlar mavjud.
#   - Ushbu kalitlarga mos qiymatlar yordamida matn to'ldirilmoqda.
# Out:
# Mening ismim Azizbek. Yoshim 20 da

# %% [markdown]
# ## 11. index()
# ---
# **Tushuntirish**: Berilgan matnda uchragan _qiymat_ ning birinchi indeksini qaytaradi. Agar _qiymat_ mavjud bo'lmasa xatolik kelib chiqadi.
#
# **Sintaksis**:
# ```python
# matn.index(value, start, stop)
# ```
#
# Bu yerda:
# - **value**(qiymat): Majburiy parametr. Faqat bilgilardan iborat matnni qabul qiladi.
#
#     Qidirilishi kerak bo'lgan matn.
# - **start**(boshlanish): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi.
#
#     _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
# - **stop**(tugash): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi.
#
#     _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi.
#
#     Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol.
matn = "Hello, welcome to my world."
natija = matn.index("e")
print(natija) 

# Tushuntirish:
#   - 'e' harfi matnda jami bo'lib 3 ta.
#   - U birinchi bo'lib 1-indeksda uchraydi.
# Out:
# 1

# %%
# Maxsus hol
matn = "Mening ismim Azizbek"
boshlanish = 1
tugash = 9
qiymat = "s"

natija = matn.index(qiymat, boshlanish, tugash) # Bu 's' harfini matn[1: 9] joyida (ya'ni 1-indeksda 8 - indekslar orasidan) izlaydi.
print(natija)
# Out:
# 8

# %% [markdown]
# ## 12. isalnum()
# ---
#
# **Tushuntirish**: Matndagi barcha belgilar harflar(a-z) yoki raqamlar(0-9) dan iborat ekanligni tekshiradi.
#
# Agar shartga mos kelsa ```True```(rost), aks holda ```False```(yolg'on) qiymatini qaytaradi.
#
#
# **Sintaksis**:
# ```python
# matn.isalnum()
# ```
#
# **Eslatma**: Agar matnda bo'sh joy(" "), ?, !, # va h.k. larga o'xshagan belgilar mavjud bo'lsa ```False``` qaytaradi.

# %%
# Oddiy hol: Ortiqcha belgilarsiz.
matn = "Azizbek20"
natija = matn.isalnum()

if natija:
    print("Matnda ortiqcha belgilar mavjud emas.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matnda ortiqcha belgilar mavjud emas.

# %%
# Oddiy hol: Faqat harflar
matn = "Azizbek"
natija = matn.isalnum()

if natija:
    print("Matnda ortiqcha belgilar mavjud emas.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matnda ortiqcha belgilar mavjud emas.

# %%
# Oddiy hol: Faqat raqamlar
matn = "20"
natija = matn.isalnum()

if natija:
    print("Matnda ortiqcha belgilar mavjud emas.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matnda ortiqcha belgilar mavjud emas.

# %%
# Maxsus hol: Harf, raqam va ortiqcha belgilar
matn = "Azizbek 20?"
natija = matn.isalnum()

if natija:
    print("Matnda ortiqcha belgilar mavjud emas.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matnda ortiqcha belgilar mavjud.

# %% [markdown]
# ## 13. isalpha()
# ---
#
# **Tushuntirish**: Matndagi barcha belgilar faqat harflardan(a-z) iborat ekanligini tekshiradi.
#
# Aytilgan shartga mos kelsa ```True``` qaytaradi. Agar matnda raqamlar(0-9), bo'sh joy(' '), ?,
#
# yoki h.k kabi belgilar bo'lsa ```False``` qaytardi.
#
# **Sintaksis**:
# ```
# matn.isalpha()
# ```

# %%
# Oddiy hol: Faqat harflardan iborat matn.
matn = "Salom"
natija = matn.isalpha()

if natija:
    print("Matn faqat harflardan iborat.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matn faqat harflardan iborat.

# %%
# Maxsus hol: Harflar, raqamlar va ortiqcha(qo'shimcha) belgilardan iborat matn
matn = "Salom 307-guruh talabalari!"
natija = matn.isalpha()

if natija:
    print("Matn faqat harflardan iborat.")
else:
    print("Matnda ortiqcha belgilar mavjud.")
# Out:
# Matnda ortiqcha belgilar mavjud.

# %% [markdown]
# ## 14. isascii()
# ---
#
# **Tushuntirish**: Agar matndagi barcha belgilar ascii belgilari bo'lsa ```True```(rost), aks
#
# holda ```False```(yolg'on) qiymatni qaytaradi.
#
# **Sintaksis**:
# ```python
# matn.isascii()
# ```
#
# **Batafsil**: [Ascii belgilari](https://www.w3schools.com/charsets/ref_html_ascii.asp)

# %%
# Oddiy hol
matn = "Kompaniya12"
natija = matn.isascii()

if natija:
    print("Matn ascii belgilaridan iborat")
else:
    print("Matn ascii belgilaridan iborat emas.")
# Out:
# Matn ascii belgilaridan iborat

# %% [markdown]
# ## 15. isdecimal()
# ---
#
# **Tushuntirish**: Agar satr(matn)da barcha belgilar faqat raqamlardan(0-9) iborat bo'lsa
#
# ```True```(rost), aks holda ```False```(yolg'on) qiymatni qaytaradi.
#
# **Sintaksis**:
# ```python
# matn.isdecimal()
# ```

# %%
# Oddiy hol: Faqat raqamlar
matn = "123"
natija = matn.isdecimal()

if natija:
    print("Matn faqat raqamli belgilardan iborat")
else:
    print("Matnda harflar yoki ortiqcha belgilar qatnashgan.")
# Out:
# Matn faqat raqamli belgilardan iborat

# %%
# Oddiy hol: Raqamlar va harflar
matn = "123abs"
natija = matn.isdecimal()

if natija:
    print("Matn faqat raqamli belgilardan iborat")
else:
    print("Matnda harflar yoki ortiqcha belgilar qatnashgan.")
# Out:
# Matnda harflar yoki ortiqcha belgilar qatnashgan.

# %%
# Maxsus hol: Belgilarni Yunikod(Unikod) yordamida tekshirish
a = "\u0030" # 0 ning yunikod raqami
b = "\u0047" # G ning yunikod raqami

print(a.isdecimal())
print(b.isdecimal())
# Out:
# True
# False

# %% [markdown]
# ## 16. isdigit()
# ---
#
# **Tushuntirish**: Agar satr(matn)da barcha belgilar faqat sonlardan iborat bo'lsa ```True```
#
# (rost), aks holda ```False```(yolg'on) qiymatni qaytaradi.
#
# **Sintaksis**:
# ```python
# matn.isdigit()
# ```
#
#
# **Eslatma**: Darajalar(² kabi) ham son(digit) hisoblanadi.

# %%
# Oddiy hol
matn = "12.01"
natija = matn.isdecimal()
natija
# Out:
# False

# %%
# Oddiy hol
matn = "12"
natija = matn.isdigit()
natija
# Out:
# True

# %%
# Maxsus hol: Yunikodlar yordamida
a = "\u0030" # 0 ning yunikod raqami
b = "\u00B2" # ² ning yunikod raqami

print(a.isdigit())
print(b.isdigit())
# Out:
# True
# True

# %% [markdown]
# ## 17. isidentifier()
# ---
#
# **Tushuntirish**: Agar matn  haqiqit identifikator(aniqlagich) bo'lsa ```True```(rost), aks
#
# holda```False```(yolg'on) qiymatini qaytaradi.
#
# **Sintaksis**:
# ```python
# matn.isidentifier()
# ```
#
# **Eslatma**: Matn identifikator bo'lishi uchun birinchi belgisi raqam bo'lmasiligi kerak.
#
# Matnda pastki chiziqcha yoki raqamlar(0-9) va harflardan(a-z) iborat bo'lishi kerak.
#
# Identifikatorda hech qanday ortiqcha belgi(bo'sh joy, ?, ! va h.k) lar ishtirok etmasligi
#
# kerak.

# %%
# Bir nechta hol
a = "MeningHujjatim"
b = "Dasturchi12"
c = "Dasturhi_12"
d = "1_Dasturchi"
e = "1 Dastirchi"
f = "12Dasturchi"

print(a.isidentifier())
print(b.isidentifier())
print(c.isidentifier())
print(d.isidentifier())
print(e.isidentifier())
print(f.isidentifier())
# Out:
# True
# True
# True
# False
# False
# False

# %% [markdown]
# ## 18. islower()
# ---
#
# **Tushuntirish**: Agar matndagi barcha belgilar kichik harflardan iborat bo'lsa ```True```,
#
# aks holda ```False```(yolg'on) qiymatni qaytaradi. Matnda raqamlar va bo'sh joylar bo'lsa
#
# ular tekshirib o'tirilmaydi. Faqat harflar tekshriladi.
#
# **Sintaksis**:
# ```python
# matn.islower()
# ```

# %%
# Oddiy hol: Katta-kichik harflar
matn = "Salom Dunyo"
natija = matn.islower()

print("Matnda faqat kichik harflardan iborat" if natija else "Matnda katta harflar mavjud.")
# Out:
# Matnda katta harflar mavjud.

# %%
# Oddiy hol: Raqam va bo'sh joy mavjud matn
matn = "salom aziz12"
natija = matn.islower()

print("Matnda faqat kichik harflardan iborat" if natija else "Matnda katta harflar mavjud.")
# Out:
# Matnda faqat kichik harflardan iborat

# %%
# Oddiy hol: Faqat kichik harflar
matn = "salom"
natija = matn.islower()

print("Matnda faqat kichik harflardan iborat" if natija else "Matnda katta harflar mavjud.")
# Out:
# Matnda faqat kichik harflardan iborat

# %% [markdown]
# ## 19. isnumeric()
# ---
#
# **Tushuntirish**: Agar matnning barcha belgilar raqamlardan(0-9), darajalar yoki  ² va ¾ kabi belgilardan iborat bo'lsa,
#
# ```True```(rost), aks holda ```False```(yolg'on) qiymatini qaytaradi. Manfiy va o'nlik kasrlar (-1, 1.5 kabi) sonlardan
#
# iborat bo'lsa ```False``` qaytaradi.
#
# **Sintaksis**:
# ```python
# matn.isnumeric()
# ```

# %%
# Oddiy hol: Faqat raqamlar
matn = "123456"
natija = matn.isnumeric()
natija
# Out:
# True

# %%
# Maxsus hol: Raqam va harflar aralash
matn = "10km2"
natija = matn.isnumeric()
natija
# Out:
# False

# %%
# Maxsus hol: Manfiy sonlar
matn = "-2"
natija = matn.isnumeric()
natija
# Out:
# False

# %%
# Maxsus hol: Kvadrat daraja(a^2) kabi hol
matn = "\u00B2" # &sup2 uchun yunikod
natija = matn.isnumeric()
natija
# Out:
# True

# %%
# Maxsus hol: O'nlik kasr ko'rinishida
matn = "1.2"
natija = matn.isnumeric()
natija
# Out:
# False

# %% [markdown]
# ## 20. isprintable()
# ---
#
# **Tushuntirish**: Agar satrdagi barcha belgilar ko'rinadigan (a, b, @, # va h.k. kabi) bo'lsa ```True``` (rost),
#
# agar satrda chop etilmydigan belgilar (masalan \t, \n, \r kabi) belgilar mavjud bo'lsa ```False```(yolg'on)
#
# qiymatini qaytaradi.
#
# **Sintaksis**:
# ```
# matn.isprintable()
# ```

# %%
# Oddiy hol: Shartga mos
matn = "Salom Python dasturchilar! Men bilan bog'laning. Profil azizbek@123"
natija = matn.isprintable()
natija
# Out:
# True

# %%
# Maxsus hol: Shartga mos bo'lmagan(\n, \t)
matn = "Salom Python dasturchilar!\n Men bilan\t bog'laning. Profil azizbek@123"
natija = matn.isprintable()
natija
# Out:
# False

# %% [markdown]
# ## 21. isspace()
# ---
#
# **Tushuntirish**: Agar satrdagi barcha belgilar faqat bo'sh joydan iborat bo'lsa ```True```
#
# (rost), aks holda ```False```(yolg'on) qiymatini qaytaradi.
#
# **Sintaksis**:
# ```
# matn.isspace()
# ```

# %%
# Oddiy hol: Faqat bo'sh joy(" ")
matn = "     "
natija = matn.isspace()
natija
# Out:
# True

# %%
# Maxsus hol: Harf va bo'sh joy
matn = "   a  "
natija = matn.isspace()
natija
# Out:
# False

# %% [markdown]
# ## 22. istitle()
# ---
#
# **Tushuntirish**: Agar satrdagi har bir so'z katta harfdan boshlanib, qolgan harflari esa kichik bo'lsa ```True```
#
# (rost), aks holda ```False```(yolgo'n) qiymatini qaytaradi. Agar birichi belgi raqam yoki ortiqcha belgi  bo'lsa
#
# e'tiborga olinmaydi. Agar matndagi biror so'zi ichida raqam yoki ortiqcha belgi qatnashsa ```False``` qaytaradi.
#
# **Sintaksis**:
# ```
# matn.istitle()
# ```

# %%
# Oddiy hol: Shartga mos
matn = "Salom Qadrli Dasturchilar."
matn.istitle()
# Out:
# True

# %%
# Maxsus hol: Agar birinchi belgi raqam bo'lsa
matn = "9 Dasturchilar"
matn.istitle()
# Out:
# True

# %%
# Maxsus hol: Agar biror so'z ichida raqam qatnashsa
matn = "Salom Dastur12chilar"
matn.istitle()
# Out:
# False

# %%
# Maxsus hol: Agar matnning ixtiyoriy qismida sonlar bo'lsa.
matn = "12 Dasturchi 5 Ta Dasturlash Tilini Biladi."
matn.istitle()
# Out:
# True

# %%
# Maxsus hol: So'z ichida ortiqcha belgi bo'lsa
matn = "Dassturchilar Soni 5 Ta?mi" # 
matn.istitle()
# Out:
# False

# %%
# Maxsus hol: Agar barcha belgilar katta harflardan iborat bo'lsa.
matn = "SALOM DASTURCHI"
matn.istitle()
# Out:
# False

# %% [markdown]
# ## 23. isupper()
# ---
#
# **Tushuntirish**: Agar matndagi barcha belgilar katta harflardan iborat bo'lsa ```True```(rost),
#
# aks holda ```False```(yolg'on) qiymatini qaytaradi. Raqamlar va ortiqcha belgilarn inobatga olinmaydi.
#
# **Sintaksis**:
# ```
# matn.isupper()
# ```

# %%
# Oddiy hol
matn = "SALOM DASTURCHILAR!"
matn.isupper()
# Out:
# True

# %%
# Maxsus hol: So'z ichida raqam bo'lsa
matn = "SALOM DAS1URCHI!"
matn.isupper()
# Out:
# True

# %%
# Maxsus hol: Aralash kattalikdagi matn
matn = "Men SEN biLAN"
matn.isupper()
# Out:
# False

# %% [markdown]
# ## 24. join()
# ---
#
# **Tushuntirish**: List(ro'yxat), tuple(qator) va h.k. ma'lumot turidagi elementlardan yangi matn hosil qiladi.
#
# **Sintaksis**:
# ```
# yangi_matn = "boluchi_element".join(iterable)
# ```
#
# Bu yerda:
# -   **iterable**: Majburiy parametr. List(ro'yxat), tuple(qator), dict(lug'at) va shunga o'xshash ma'lumotlar ketma-yori.
# -   **boluvchi element**: Bu ixtiyoriy satr.

# %%
# Oddiy hol: Ro'yxat elementlari yordaminda yangi matn tuzish
royxat = ["C++", "Python", "Java"]
matn = " ".join(royxat)
print(matn)

# Tushuntirish:
#   - 3 ta elementdan iborat ro'yxat hosil qilinmoqda.
#   - Bo'sh joy(" ") va ro'yxat elementlari yordamida yangi matn hosil qilinmoqda.
# Out:
# C++ Python Java

# %%
# Maxsus hol: Har turdagi elementda iborat bo'lgan ro'yxat
royxat = ["Python", 3.14, True]
try:
    matn = " ".join(royxat)
except TypeError:
    print("Ro'yxatning har bir elementi str(matn) turiga mansub bo'lishi kerak")
else:
    print(matn)
# Out:
# Ro'yxatning har bir elementi str(matn) turiga mansub bo'lishi kerak

# %%
# Oddiy hol: Tuple(qator) ma'lumot turidan foydalanih
qator = ("Salom", "qadrli", "Python", "dasturchilari")
try:
    matn = " ".join(qator)
except TypeError:
    print("Ro'yxatning har bir elementi str(matn) turiga mansub bo'lishi kerak")
else:
    print(matn)
# Out:
# Salom qadrli Python dasturchilari

# %%
# Oddiy hol: Set(to'plam) ma'lumot turidan foydalanih
toplam = {"Salom", "qadrli", "Python", "dasturchilari"}
try:
    matn = " ".join(toplam)
except TypeError:
    print("Ro'yxatning har bir elementi str(matn) turiga mansub bo'lishi kerak")
else:
    print(matn)
# Out:
# Salom qadrli dasturchilari Python

# %%
# Maxsus hol: Dict(lug'at) ma'lumot turidan foydalanish
lugat = {"Dasturchi": "Azizbek Jabborov", "Yoshi": 18, "Mutaxasisligi": "AI engineer"}
try:
    matn = " | ".join(lugat)
except TypeError:
    print("Ro'yxatning har bir elementi str(matn) turiga mansub bo'lishi kerak")
else:
    print(matn)

# Tushuntirsh:
#   - 3 ta kalit-qiymat juftligidan iborat lug'at yaratilmoqda,
#   - Ularning kalitlari: ["Dasturchi", "Yoshi", "Mutaxasisligi"]
#   - join funksiyasi lug'at bilan ishlatilganda uning kalitlari olindadi.
#   - Yangi matn " | " satri yordamida yaratilmoqda.
# Out:
# Dasturchi | Yoshi | Mutaxasisligi

# %% [markdown]
# ## 25. ljust()
# ---
#
# **Tushuntirish**: Berilgan matndan yangi _length_(uzunlikdagi) yangi matn yaratiladi. Matn
#
# chap tomonga o'tiladi, qolgan qismlariga _character_(belgi) bilan to'ldiriladi.
#
# **Sintaksis**:
# ```
# matn.ljust(length, character)
# ```
#
# Bu yerda:
# -   **length**(uzunlik): Majburiy parametr. Yangi satrning uzunligi.
# -   **character**(belgi): Ixtiyoriy parametr. Faqat bitta belgidan iborat bo'lishi kerak.
#
#     Ortiqcha joylatini to'ldirish uchun belgi. Jimlik bo'yicha bo'sh qiymat(" ").

# %%
# Oddiy hol: Bo'sh qiymat bilan ishlash
matn = "Python"
yangi_matn = matn.ljust(20)
print(yangi_matn, "- bu eng ommabop dasturlash tili.")

# Tushuntirsh:
#   - 6 ta belgidan iborat matn yaratilmoqda.
#   - 20 ta belgidan iborat yangi matn yaratilmoqda.
#   - Yangi matnda 6 ta belgi va 14 ta bo'sh joy mavjud.
#   - Yangi matn uzunligi: 20.
#   - Avvalgi matn chap tomondan o'rin olgan.
# Out:
# Python               - bu eng ommabop dasturlash tili.

# %%
# Maxsus hol: Boshqa belgi bilan to'ldirish
matn = "Python"
yangi_matn = matn.ljust(20, '^')
print(yangi_matn, "- bu eng ommabop dasturlash tili.")

# Tushuntirsh:
#   - 6 ta belgidan iborat matn yaratilmoqda.
#   - 20 ta belgidan iborat yangi matn yaratilmoqda.
#   - Yangi matnda 6 ta harf va 14 ta '^' belgisi mavjud.
#   - Yangi matn uzunligi: 20.
#   - Avvalgi matn chap tomondan o'rin olgan.
# Out:
# Python^^^^^^^^^^^^^^ - bu eng ommabop dasturlash tili.

# %% [markdown]
# ## 26. lower()
# ---
#
# **Tushuntirish**: Berilgan matnda barcha harflarni kichik harflarga o'zgartirib yangi matn yaratadi.
#
# Raqamlar va simvolli belgilar inobatga olinmyadi.
#
# **Sintaksis**:
# ```
# matn.lower()
# ```

# %%
# Oddiy hol: Aralash matn
matn = "SaloM DasTURchi"
matn.lower()
# Out:
# 'salom dasturchi'

# %% [markdown]
# ## 27. lstrip()
# ---
#
# **Tushuntirish**: Matnning chap tomonidan belgilarni olib tashlaydi.
#
# **Sintaksis**:
# ```
# matn.lstrip(characters)
# ```
#
# Bu yerda:
# -   **characters**(belgilar): Ixtiyoriy parametr. O'chirilishi kerak bo'lgan belgi(lar)dan iborat matn.
#
#     Jimlik bo'yicha bo'sh joy(" ")

# %%
# Oddiy hol: Chap tomodangi bo'sh joylarni o'chrish.
matn = "    Dasturchi   "
matn.lstrip()
# Out:
# 'Dasturchi   '

# %%
# Maxsus hol: Bir nechda belgidan iborat
matn = "aabaaaasasturbchi   "
matn.lstrip("ab")

# Tushuntirish:
#   - Chap tomondan belgilarni tekshrish boshlanadi.
#   - Agar belgi 'a' yoki 'b' bilan bir xil bo'lsa o'chiriladi.
#   - Agar boshqa belgi masalan 's' bo'lsa o'chirish to'xtatiladi.
# Out:
# 'sasturbchi   '

# %% [markdown]
# ## 28. maketrans()
# ---
#
# **Tushutirish**: ```translate()``` metodi uchun qolip yaratadi. Batafsil ```translate()``` metodida ko'ring.
#
# **Sintaksis**
# ```
# str.maketrans(x, y, z)
# ```
#
# Bu yerda:
# -   **x**: Majburiy parametr. Agar bitta belgidan iborat bo'lsa mantdgai barcha shu parametrga o'xshash barcha belgilar
#
#     yangisiga o'zgartirladi. Agar ikki va undan ortiq belgilardan iborat bo'lsa, ikkinchi parametr ```y``` dagi elementlarning
#
#     joylashuviga qarab o'zgartiriladi.
#
# - **y**: Ixtiyoriy parametr. ```x``` parametrining uzunligi bilan bir xil bo'lishi kerak. ```x``` dagi belgilarni o'zgartirish
#
#     uchun belgilar ketma-ketligi.
#
# - **z**: Ixtiyoriy parametr. Matnda qaysi belgilar olib tashlash(o'chiris) kerakligini aniqlaydi.

# %%
# Oddiy hol: Barcha 'S' belilarini 'P'ga o'zgartirish
matn = "Hello Sam!"
qolip = str.maketrans("S", "P")
yangi_matn = matn.translate(qolip)
yangi_matn
# Out:
# 'Hello Pam!'

# %%
# Maxsus hol: Bir nechta belgilarni birdaniga o'zgartirish 
matn = "Hi Sam!"
x = "mSa"
y = "eJo"
qolip = str.maketrans(x, y)
matn.translate(qolip)

# Tushuntirish:
#   - Matndagi barcha 'm' -> 'e' ga, 'S' -> 'J' ga va 'a' -> 'o' ga o'zgartirilmoqda.
# Out:
# 'Hi Joe!'

# %%
# Maxsus hol: Bir nechta belgilarni birdaniga o'zgartirish va keraksiz belgilarni o'chirish
matn = "Hi Sam!!?"
x = "mSa"
y = "eJo"
z = "?!"
qolip = str.maketrans(x, y, z)
matn.translate(qolip)

# Tushuntirish:
#   - Matndagi barcha 'm' -> 'e' ga, 'S' -> 'J' ga va 'a' -> 'o' ga o'zgartirilmoqda.
#   - Matndagi '?' va '!' belgilari o'chirilmoqda.
# Out:
# 'Hi Joe'

# %% [markdown]
# ## 29. partition()
# ---
#
# **Tushntirish**: Matnni _value_(qiymat) asosida 3 qismga bo'lib, barchasini bitta qator(tuple) elementiga
#
# qo'shib qaytaradi. Natija quyidagicha bo'ladi: ```('birinchi qism', 'value(qiymat)', 'ikkinchi qism')```
#
# **Sintaksis**:
# ```
# matn.partiton(value)
# ```
#
# Bu yerda:
# -   **value**(qiymat): Majburiy parametr. Bo'luvchi element.

# %%
# Oddiy hol: 'Python' so'zi bilan bo'lish
qism = "Python"
matn = "Salom qadrli Python dasturchilari."
matn.partition(qism)
# Out:
# ('Salom qadrli ', 'Python', ' dasturchilari.')

# %%
# Maxsus hol: Mavjud bo'lmagan so'z bilan bo'lish('java' orqali)
qism = "java"
matn = "Salom qadrli Python dasturchilari."
matn.partition(qism)
# Out:
# ('Salom qadrli Python dasturchilari.', '', '')

# %% [markdown]
# ## 30. replace()
# ---
#
# **Tushuntirish**: Matndagi biror belgini o'zgartirish uchun ishlatiladi.
#
# **Sintaksis**
# ```
# matn.replace(oldvalue, newvalue, count)
# ```
#
# Bu yerda:
# -   **oldvalue**(eski qiymat): Majburiy parametr. O'zgaritirlishi kerak bo'lgan belgi.
# -   **newvalue**(yangi qiymat): Majburiy parametr. Qaysi belgiga o'zgartirlishi kerakligini aniqlaydi.
# -   **count**(soni): Dastlabki ma'lum bir sonini o'zgartirish.

# %%
# Oddiy hol.
matn = "Salom Jabborov"
eski_qiymat = "Jabborov"
yangi_qiymat = "Azizbek"
matn.replace(eski_qiymat, yangi_qiymat)
# Out:
# 'Salom Azizbek'

# %%
# Maxsus hol.
matn = "Salom Jabborov Jabborov"
eski_qiymat = "Jabborov"
yangi_qiymat = "Azizbek"
soni = 1
matn.replace(eski_qiymat, yangi_qiymat, soni)

# Tushutirish:
#   - Faqat birinchi 'Jabborov' so'zini o'zgartiradi.
# Out:
# 'Salom Azizbek Jabborov'

# %% [markdown]
# ## 31. rfind()
# ---
#
# **Tushuntirish**: Matnda maxsus _qiymat_ borligini tekshradi. Agar mavjud bo'lsa uchralgan oxirgi indeksni qaytardi, aks holda ```-1```.
#
# **Sintaksis**:
# ```
# matn.rfind(value, start, stop)
# ```
#
# Bu yerda:
# - **value**(qiymat): Majburiy parametr. Faqat bilgilardan iborat matnni qabul qiladi.
#
#     Qidirilishi kerak bo'lgan matn.
#
# - **start**(boshlanish): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi.
#
#      _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
#
# - **stop**(tugash): Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi. o indeks
#
#     _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi.
#
#     Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol: Faqat majburiy parametr bilan
matn = "Salom Azizbek, Salom!"
qiymat = "Salom"
natija = matn.rfind(qiymat)
print(f"'{qiymat}' so'zi matnda mavjud. Uni {natija}-indeksdan boshlab ko'rishingiz mumkin!")
# Out:
# 'Salom' so'zi matnda mavjud. Uni 15-indeksdan boshlab ko'rishingiz mumkin!

# %%
# Maxsus hol: Barcha parametrlar bilan
matn = "Salom Azizbek, Salom!"
qiymat = "Salom"
boshlanish = 10
tugash = 21
natija = matn.rfind(qiymat, boshlanish, tugash)
print(f"'{qiymat}' so'zi matnning {boshlanish}-indeksidan {tugash}-indeksigacha mavjud.\
 Uni {natija}-indeksdan boshlab ko'rishingiz mumkin!\
      ")
# Out:
# 'Salom' so'zi matnning 10-indeksidan 21-indeksigacha mavjud. Uni 15-indeksdan boshlab ko'rishingiz mumkin!

# %% [markdown]
# ## 32. rjust()
# ---
#
# **Tushuntirish**: Berilgan matndan yangi _length_(uzunlikdagi) yangi matn yaratiladi. Matn
#
# o'ng tomonga o'tiladi, qolgan qismlariga _character_(belgi) bilan to'ldiriladi.
#
# **Sintaksis**:
# ```
# matn.rjust(length, character)
# ```
#
# Bu yerda:
# -   **length**(uzunlik): Majburiy parametr. Yangi satrning uzunligi.
# -   **character**(belgi): Ixtiyoriy parametr. Faqat bitta belgidan iborat bo'lishi kerak.
#
#     Ortiqcha joylatini to'ldirish uchun belgi. Jimlik bo'yicha bo'sh qiymat(" ").

# %%
# Oddiy hol: Bo'sh qiymat bilan ishlash
matn = "Python"
yangi_matn = matn.rjust(20)
print(yangi_matn, "- bu eng ommabop dasturlash tili.")

# Tushuntirsh:
#   - 6 ta belgidan iborat matn yaratilmoqda.
#   - 20 ta belgidan iborat yangi matn yaratilmoqda.
#   - Yangi matnda 6 ta belgi va 14 ta bo'sh joy mavjud.
#   - Yangi matn uzunligi: 20.
#   - Avvalgi matn o'ng tomondan o'rin olgan.
# Out:
#               Python - bu eng ommabop dasturlash tili.

# %%
# Maxsus hol: Boshqa belgi bilan to'ldirish
matn = "Python"
yangi_matn = matn.rjust(20, '^')
print(yangi_matn, "- bu eng ommabop dasturlash tili.")

# Tushuntirsh:
#   - 6 ta belgidan iborat matn yaratilmoqda.
#   - 20 ta belgidan iborat yangi matn yaratilmoqda.
#   - Yangi matnda 6 ta harf va 14 ta '^' belgisi mavjud.
#   - Yangi matn uzunligi: 20.
#   - Avvalgi matn o'ng tomondan o'rin olgan.
# Out:
# ^^^^^^^^^^^^^^Python - bu eng ommabop dasturlash tili.

# %% [markdown]
# ## 33. rpartition()
# ---
#
# **Tushntirish**: Matnni oxirgi uchralgan _value_(qiymat) asosida 3 qismga bo'lib, barchasini bitta qator(tuple) elementiga
#
# qo'shib qaytaradi. Natija quyidagicha bo'ladi: ```('birinchi qism', 'value(qiymat)', 'ikkinchi qism')```
#
# **Sintaksis**:
# ```
# matn.rpartiton(value)
# ```
#
# Bu yerda:
# -   **value**(qiymat): Majburiy parametr. Bo'luvchi element.

# %%
# Oddiy hol: 'Python' so'zi bilan bo'lish
qism = "Python"
matn = "Salom Pythonchilar, qadrli Python dasturchilari."
matn.rpartition(qism)
# Out:
# ('Salom Pythonchilar, qadrli ', 'Python', 'c dasturchilari.')

# %%
# Maxsus hol: Mavjud bo'lmagan so'z bilan bo'lish('java' orqali)
qism = "java"
matn = "Salom Pythonchilar, qadrli Python dasturchilari."
matn.rpartition(qism)
# Out:
# ('', '', 'Salom Pythonchilar, qadrli Python dasturchilari.')

# %% [markdown]
# ## 34. rsplit()
# ---
#
# **Tushuntirish**: Matnni bo'laklarga bo'lib, bitta ro'yxat(list) orqali qaytaradi.
#
# Bo'lakka bo'lishni o'ng tomondan boshlaydi.
#
# **Sintaksis**:
# ```
# matn.rsplit(separator, maxsplit)
# ```
#
# Bu yerda:
# -   **separator**: Ixtiyoriy parametr. Matnni bo'lakka bo'luvchi kichik satr. Jimlik bo'yicha bo'sh joy(" ").
# -   **maxsplit**: Ixtiyoriy parametr. Nechta bo'lakka bo'lishni bildiradi. Jimlik bo'yicha ```-1```(bu barcha
#
#     bo'laklarni bildiradi.)
#
#     **1-Eslatma**: Agar siz ```2``` kiritsangiz matnni ```3``` ta bo'lakka ajratadi.
#
#     **2-Eslatma**: Agar bu parametrga qiymat kiritmasangiz, ```split()``` metodi bilan bir xil ishlaydi.

# %%
# Oddiy hol: Barchasini bo'lakka bo'lish
matn = "Python, C++, Java, HTML"
separator = ", " # ',' va bo'sh joy asosida bo'lish
matn.rsplit(sep=separator)
# Out:
# ['Python', 'C++', 'Java', 'HTML']

# %%
# Maxsus hol: Bir qancha qismini bo'lakka bo'lish
matn = "Python, C++, Java, HTML"
separator = ", " # ',' va bo'sh joy asosida bo'lish
maxsplit = 2 # Matnda 2 ta element ajratib olinadi, qolgani o'z holida turadi.
matn.rsplit(sep=separator, maxsplit=maxsplit)

# Tushuntirish:
#   - Matnning qolgan qismi 1-element, 2- va 3-elementlar esa 2 ta bo'lak.
# Out:
# ['Python, C++', 'Java', 'HTML']

# %% [markdown]
# ## 35. rstrip()
# ---
#
# **Tushuntirish**: Matnning o'ng tomonidan belgilarni olib tashlaydi.
#
# **Sintaksis**:
# ```
# matn.lstrip(characters)
# ```
#
# Bu yerda:
# -   **characters**(belgilar): Ixtiyoriy parametr. O'chirilishi kerak bo'lgan belgi(lar)dan iborat matn.
#
#     Jimlik bo'yicha bo'sh joy(" ")

# %%
# Oddiy hol: O'ng tomodangi bo'sh joylarni o'chrish.
matn = "    Dasturchi   "
matn.rstrip()
# Out:
# '    Dasturchi'

# %%
# Maxsus hol: Bir nechda belgidan iborat
matn = "   asturbchiaabaaaa"
matn.rstrip("ab")

# Tushuntirish:
#   - O'ng tomondan belgilarni tekshrish boshlanadi.
#   - Agar belgi 'a' yoki 'b' bilan bir xil bo'lsa o'chiriladi.
#   - Agar boshqa belgi masalan 'i' bo'lsa o'chirish to'xtatiladi.
# Out:
# '   asturbchi'

# %% [markdown]
# ## 36. split()
# ---
#
# **Tushuntirish**: Matnni bo'laklarga bo'lib, bitta ro'yxat(list) orqali qaytaradi.
#
# Bo'lakka bo'lishni chap tomondan boshlaydi.
#
#
# **Sintaksis**:
# ```
# matn.split(separator, maxsplit)
# ```
#
# Bu yerda:
# -   **separator**: Ixtiyoriy parametr. Matnni bo'lakka bo'luvchi kichik satr. Jimlik bo'yicha bo'sh joy (```" "```).
# -   **maxsplit**: Ixtiyoriy parametr. Nechta bo'lakka bo'lishni bildiradi. Jimlik bo'yicha ```-1```(bu barcha
#
#     bo'laklarni bildiradi)
#
#     **Eslatma**: Agar siz ```2``` kiritsangiz matnni ```3``` ta bo'lakka ajratadi.

# %%
# Oddiy hol: Barchasini bo'lakka bo'lish
matn = "Python, C++, Java, HTML"
separator = ", " # ',' va bo'sh joy asosida bo'lish
matn.rsplit(sep=separator)
# Out:
# ['Python', 'C++', 'Java', 'HTML']

# %%
# Maxsus hol: Bir qancha qismini bo'lakka bo'lish
matn = "Python, C++, Java, HTML"
separator = ", " # ',' va bo'sh joy asosida bo'lish
maxsplit = 2 # Matnda 2 ta element ajratib olinadi, qolgani o'z holida turadi.
matn.split(sep=separator, maxsplit=maxsplit)

# Tushuntirish:
#   - 1- va 2-elementlari 2 ta bo'lak, Matnning qolgan qismi esa 3-element
# Out:
# ['Python', 'C++', 'Java, HTML']

# %% [markdown]
# ## 37. splitlines()
# ---
#
# **Tushuntirish**: Matnni yangi qator(```\n```) asosida bo'laklarga bo'lib, bitta ro'yxat(list) orqali qaytaradi.
#
# **Sintaksis**:
# ```
# matn.split(keeplinebreaks)
# ```
#
# Bu yerda:
# -   **keeplinebreaks**: Ixtiyoriy parametr. Matnni bo'lakka bo'lganda yangi qator(```\n```) belgisi qoldirilish yoki
#
#     yo'qligni bildiruvchi mantiqiy(boolean) qiymat. Jimlik bo'yicha bo'sh joy (```False```).

# %%
# Oddiy hol: \n belgisini olib qoldirish
matn = "Python\nC++\nJava"
matn.splitlines()
# Out:
# ['Python', 'C++', 'Java']

# %%
# Maxsus hol: \n belgilarini qoldirish
matn = "Python\nC++\nJava"
keeplinebreaks = True
matn.splitlines(keepends=keeplinebreaks)
# Out:
# ['Python\n', 'C++\n', 'Java']

# %% [markdown]
# ## 38. startswith()
# ---
#
# **Tushuntirish**: Agar matn berilgan _qiymat_ bilan boshlansa ```True```(rost) qaytaradi, aks holda ```False```(yolg'on).
#
# **Sintaksis**:
# ```
# matn.startsswith(qiymat, boshlanish, tugash)
# ```
#
# Bu yerda:
# - **qiymat**: Majburiy parametr. String(matn) yoki tuple(qator) bo'lishi mumkin.
#
#     Agar tuple kiritilgan bo'lsa va matnning oxiri tuple ichidagi birorta element bilan tugasa rost qaytaradi.
# - **boshlanish**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi.
#
#     _qiymat_ ni qaysi indeksdan boshlab qidirishini belgilaydi. Jimlik bo'yicha 0.
# - **tugash**: Ixtiyoriy parametr. Butun son(integer)ni qabul qiladi.
#
#     _qiymat_ ni qaysi indeksgacha qidirishini belgilaydi. Jimlik bo'yicha matnning oxirgi indeksi.

# %%
# Oddiy hol
matn = "Mening ismim Azizbek"
qism = "Men"
natija = matn.startswith(qism)

if natija:
    print(f"Berilgan matn '{qism}' so'zi bilan boshlanadi.")
else:
    print(f"Berilgan matn '{qism}' so'zi bilan boshlanmaydi.")
# Out:
# Berilgan matn 'Men' so'zi bilan boshlanadi.

# %%
# Maxsus hol: Kerakli qismdan izlash
matn = "Mening ismim Azizbek"
qism = "im"
boshlanish = 10
tugash = len(matn) - 2
natija = matn.startswith(qism, boshlanish, tugash)

if natija:
    print(f"Berilgan matn {boshlanish}-indeksdan  {tugash - 1}-indeksi oralig'ida '{qism}' so'zi bilan boshlanadi.")
    print(f"Kerakli qism: {matn[boshlanish: tugash]}")
else:
    print(f"Berilgan matn {boshlanish}-indeksdan  {tugash - 1}-indeksi oralig'ida '{qism}' so'zi bilan boshlanmaydi.")
    print(f"Kerakli qism: {matn[boshlanish: tugash]}")
# Out:
# Berilgan matn 10-indeksdan  17-indeksi oralig'ida 'im' so'zi bilan boshlanadi.
# Kerakli qism: im Azizb

# %%
# Maxsus hol.
matn = "Mening ismim Azizbek"
qismlar = ("Men", "ning")
natija = matn.startswith(qismlar)

if natija:
    print(f"Berilgan matn '{qismlar}' ichidagi biror so'z bilan boshlanadi.")
else:
    print(f"Berilgan matn '{qismlar}' ichidagi biror so'z bilan boshlanmaydi.")
# Out:
# Berilgan matn '('Men', 'ning')' ichidagi biror so'z bilan boshlanadi.

# %% [markdown]
# ## 39. strip()
# ---
#
# **Tushuntirish**: Matnning o'ng va chap tomonidan belgilarni olib tashlaydi.
#
# **Sintaksis**:
# ```
# matn.lstrip(characters)
# ```
#
# Bu yerda:
# -   **characters**(belgilar): Ixtiyoriy parametr. O'chirilishi kerak bo'lgan belgi(lar)dan iborat matn.
#
#     Jimlik bo'yicha bo'sh joy(" ")

# %%
# Oddiy hol: Chap va o'ng tomondagi bo'sh joylarni o'chirish
matn = "   Python   "
matn.strip()
# Out:
# 'Python'

# %%
# Maxsus hol: Chap va o'ng tomondagi ma'lum bir belgilarni o'chirish
matn = "#$Python$#"
belgilar = "#$"
matn.strip(belgilar)

# Tushuntirish:
#   - Matnning chap va o'ng tomoni tekshiriladi.
#   - Belgilar tekshirilganda '#' yoki '$' bo'lsa o'chiriladi.
#   - Chap tomonda ham, o'ng tomonda ham boshqa belgi masalan 'P' va
#     'n' ga duch kelinsa o'chirish to'xtatiladi.
# Out:
# 'Python'

# %% [markdown]
# ## 40. swapcase()
# ---
#
# **Tushuntirish**: Matndagi katta harflarni kichikka, kichik harflarni esa kattaga o'zgartiradi.
#
# Raqamlar va boshqa belgilar inobatga olinmaydi.
#
# **Sintaksis**:
# ```
# matn.swapcase()
# ```

# %%
matn = "SaLom PytHONchilar!!12"
matn.swapcase()
# Out:
# 'sAlOM pYThonCHILAR!!12'

# %% [markdown]
# ## 41. title()
# ---
#
# **Tushuntirish**: Matndagi har bir so'zning birinchi harfini katta harfga o'zgartiradi.
#
# Agar birinchi belgi raqam bo'lsa, ikkinchi belgisini katta harfga o'zgartiradi.
#
# **Sintaksis**:
# ```
# matn.title()
# ```

# %%
# Oddiy hol
matn = "Mening dunyoyimga xush kelibsiz"
matn.title()
# Out:
# 'Mening Dunyoyimga Xush Kelibsiz'

# %%
# Maxsus hol: Agar so'zning birinchi belgisi raqam bo'lsa
matn = "Mening 2-ofisimga xush kelibsiz"
matn.title()
# Out:
# 'Mening 2-Ofisimga Xush Kelibsiz'

# %% [markdown]
# ## 42. translate()
# ---
#
# **Tushuntirish**: Matndagi belgilarni o'zgartirish uchun ishlatiladi.
#
# **Sintaksis**:
# ```
# matn.translate(table)
# ```
#
# Bu yerda:
# -   **table**: Majburiy parametr. Lug'at(dict) yoki xarita jadvali(mapping table) ni qabul qiladi.
#
#     - Agar lug'at bilan o'zgartimoqchi bo'lsangiz, ```ascii``` kodlaridan asosida ishlang.
#     - Agar xarita jadvali bilan o'zgartimoqchi bo'lsangiz, [maketrans](#28-maketrans) metodidan foydalaning.

# %%
# Oddiy hol.
matn = "Salom Sam"
xarita = str.maketrans("S", "P") # Barcha 'S' belgisini 'P'ga o'zgartirish
matn.translate(xarita)
# Out:
# 'Palom Pam'

# %%
# Maxsus hol: Xarita yordamida. Keraksiz belgilarni o'chirib tashlash
matn = "Good night Sam!"
x = "mSa"
y = "eJo"
z = "odnght"
xarita_jadvali = str.maketrans(x, y, z)
print(matn.translate(xarita_jadvali))
# Out:
# G i Joe!

# %%
# Maxsus hol: Lug'at orqali ascii kodlari yordamida.
matn = "Good night Sam!"
lugat = {109: 101, 83: 74, 97: 111, 111: None, 100: None, 110: None, 103: None, 104: None, 116: None}
print(matn.translate(lugat))
# Out:
# G i Joe!

# %% [markdown]
# ## 43. upper()
# ---
#
# **Tushuntirish**: Berilgan matnda barcha harflarni katta harflarga o'zgartiridi.
#
# Raqamlar va simvolli belgilar inobatga olinmyadi.
#
# **Sintaksis**:
# ```
# matn.upper()
# ```

# %%
matn = "Salom Dasturchilar 121"
matn.upper()
# Out:
# 'SALOM DASTURCHILAR 121'

# %% [markdown]
# ## 44. zfill()
# ---
#
# **Tushuntirish**: Matnni yangi _length_ (uzunlik)ka yetmaguncha boshidan ```0``` raqami bilan to'ldiradi.
#
# **Sintaksis**:
# ```
# matn.zfill(length)
# ```
#
# Bu yerda:
# -   **length**(uzunlik): Majburiy parametr. Yangi matnning uzunligi.
#
#     Agar uzunlik haqiqiy matn uzunligan kichik bo'lsa, matn o'z holida qoldiriladi.

# %%
a = "hello"
b = "welcome to the jungle"
c = "10.000"

print(a.zfill(10))
print(b.zfill(10))
print(c.zfill(10))
# Out:
# 00000hello
# welcome to the jungle
# 000010.000
