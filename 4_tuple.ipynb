# %% [markdown]
# <h1 id="tuple">Qator metodlari</h1>
#
# ---
#
# > **Eslatma**: Ushbu kitobni yozishda ba'zi bir funksiyalarning parametrlarining haqiqiy nomlari xato yozilgan bo'lishi mumkin. Eng muhimi ularni ko'rsatilgan tartibda ishlatishdir.
#
# **Batafsil**: [Pythonda Lug'at metodlari](https://www.w3schools.com/python/python_ref_dictionary.asp)
#
# **Muallif**: Azizbek Jabborov
# - [Telegram](https://t.me/azizbekJabborov006)
# - [GitHub](https://github.com/azizbekjb)
# - [LinkedIn](https://www.linkedin.com/in/azizbek-jabborov-244a61343/)
#
# <h2 style="text-align: center;">Mundarija</h2>
#
# 1. <a href="#tuple-count">count</a>
# 2. <a href="#tuple-index">index</a>

# %% [markdown]
# <h2 id="tuple-count">1. count</h2>
#
# ---
# **Tushuntirish**: Qatordagi ma'lum bir elementning sonini qaytaradi.
#
# **Sintaksis**:
# ```
# qator.count(value)
# ```
#
# Bu yerda:
# - **value**(qiymat): Majburiy parametr. Qatordan qidiriluvchi element.

# %%
# Oddiy hol
qator = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)
x = qator.count(5)
print(x)
# Out:
# 2

# %% [markdown]
# <h2 id="tuple-index">2. count</h2>
#
# ---
# **Tushuntirish**: Qatordagi ma'lum bir elementning birinchi uchralgan indeksini qaytaradi.
#
# **Sintaksis**:
# ```
# qator.index(value)
# ```
#
# Bu yerda:
# - **value**(qiymat): Majburiy parametr. Qatordan qidiriluvchi element.

# %%
# Oddiy hol
qator = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)
x = qator.index(5)
print(x)
# Out:
# 5
